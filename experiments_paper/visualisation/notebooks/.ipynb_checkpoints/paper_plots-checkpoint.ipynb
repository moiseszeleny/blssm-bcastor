# %%
import numpy as np
import math
# defining constants
r = 2.  # radius
w = 0.1  # width
c1 = np.array([-3.5, 0.])  # center of shell 1
c2 = np.array([3.5, 0.])  # center of shell 2
const = math.log(1. / math.sqrt(2. * math.pi * w**2))  # normalization constant

# log-likelihood of a single shell
def logcirc(theta, c):
    d = np.sqrt(np.sum((theta - c)**2, axis=-1))  # |theta - c|
    return const - (d - r)**2 / (2. * w**2)

# log-likelihood of two shells
def loglike(theta):
    return np.logaddexp(logcirc(theta, c1), logcirc(theta, c2))

# our prior transform
def prior_transform(x):
    return 12. * x - 6.

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-5,5,size=(5000,2))

# %%
lls = [loglike(xs) for xs in x]

# %%
columns = ['a', 'b']
df = pd.DataFrame(x, columns=columns)

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
g = sns.PairGrid(df,  corner=True)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot, c=lls, s=5)
g.add_legend()

# %%
# compute likelihood surface over a 2-D grid
xx, yy = np.meshgrid(np.linspace(-6., 6., 200), np.linspace(-6., 6., 200))
L = np.exp(loglike(np.dstack((xx, yy))))

# %%
# plot result
fig = plt.figure(figsize=(6,5))
plt.scatter(xx, yy, c=L, s=0.5)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.colorbar(label=r'$\mathcal{L}$');

# %%
import dynesty
# run with all defaults
sampler = dynesty.DynamicNestedSampler(loglike, prior_transform, ndim=2)
sampler.run_nested()
res = sampler.results
# Out:
# 3220it [00:08, 187.14it/s, batch: 0 | bound: 63 | nc: 16 | ncall: 64479 | eff(%):  4.955 | loglstar:   -inf <  1.382 <    inf | logz: -1.826 +/-  0.073 | dlogz:  0.039 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3363it [00:09, 139.17it/s, batch: 0 | bound: 74 | nc: 133 | ncall: 72369 | eff(%):  4.615 | loglstar:   -inf <  1.383 <    inf | logz: -1.816 +/-  0.073 | dlogz:  0.029 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3399it [00:10, 121.94it/s, batch: 0 | bound: 77 | nc: 27 | ncall: 75069 | eff(%):  4.498 | loglstar:   -inf <  1.383 <    inf | logz: -1.814 +/-  0.073 | dlogz:  0.027 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3414it [00:10, 94.57it/s, batch: 0 | bound: 80 | nc: 67 | ncall: 76912 | eff(%):  4.410 | loglstar:   -inf <  1.383 <    inf | logz: -1.814 +/-  0.073 | dlogz:  0.026 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3426it [00:10, 91.68it/s, batch: 0 | bound: 81 | nc: 286 | ncall: 77979 | eff(%):  4.365 | loglstar:   -inf <  1.383 <    inf | logz: -1.813 +/-  0.073 | dlogz:  0.026 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3457it [00:11, 66.59it/s, batch: 0 | bound: 86 | nc: 221 | ncall: 81302 | eff(%):  4.226 | loglstar:   -inf <  1.383 <    inf | logz: -1.811 +/-  0.073 | dlogz:  0.024 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3473it [00:11, 75.97it/s, batch: 0 | bound: 87 | nc: 181 | ncall: 82115 | eff(%):  4.204 | loglstar:   -inf <  1.383 <    inf | logz: -1.811 +/-  0.073 | dlogz:  0.023 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3489it [00:12, 57.67it/s, batch: 0 | bound: 90 | nc: 27 | ncall: 84339 | eff(%):  4.112 | loglstar:   -inf <  1.383 <    inf | logz: -1.810 +/-  0.073 | dlogz:  0.023 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3514it [00:12, 59.24it/s, batch: 0 | bound: 93 | nc: 98 | ncall: 86678 | eff(%):  4.031 | loglstar:   -inf <  1.383 <    inf | logz: -1.809 +/-  0.073 | dlogz:  0.022 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3553it [00:12, 76.19it/s, batch: 0 | bound: 97 | nc: 305 | ncall: 89718 | eff(%):  3.938 | loglstar:   -inf <  1.383 <    inf | logz: -1.807 +/-  0.073 | dlogz:  0.020 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3561it [00:13, 69.74it/s, batch: 0 | bound: 98 | nc: 476 | ncall: 90815 | eff(%):  3.900 | loglstar:   -inf <  1.383 <    inf | logz: -1.807 +/-  0.073 | dlogz:  0.020 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3569it [00:13, 66.93it/s, batch: 0 | bound: 99 | nc: 56 | ncall: 91746 | eff(%):  3.869 | loglstar:   -inf <  1.383 <    inf | logz: -1.806 +/-  0.073 | dlogz:  0.019 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3576it [00:13, 65.19it/s, batch: 0 | bound: 100 | nc: 149 | ncall: 92195 | eff(%):  3.858 | loglstar:   -inf <  1.383 <    inf | logz: -1.806 +/-  0.073 | dlogz:  0.019 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3614it [00:14, 57.85it/s, batch: 0 | bound: 106 | nc: 70 | ncall: 96436 | eff(%):  3.728 | loglstar:   -inf <  1.383 <    inf | logz: -1.805 +/-  0.073 | dlogz:  0.018 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3632it [00:14, 75.94it/s, batch: 0 | bound: 107 | nc: 671 | ncall: 97596 | eff(%):  3.702 | loglstar:   -inf <  1.383 <    inf | logz: -1.804 +/-  0.073 | dlogz:  0.017 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3640it [00:14, 46.87it/s, batch: 0 | bound: 109 | nc: 245 | ncall: 98816 | eff(%):  3.665 | loglstar:   -inf <  1.383 <    inf | logz: -1.804 +/-  0.073 | dlogz:  0.017 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3647it [00:14, 47.59it/s, batch: 0 | bound: 110 | nc: 157 | ncall: 99327 | eff(%):  3.653 | loglstar:   -inf <  1.383 <    inf | logz: -1.804 +/-  0.073 | dlogz:  0.016 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3653it [00:15, 34.91it/s, batch: 0 | bound: 112 | nc: 18 | ncall: 101078 | eff(%):  3.596 | loglstar:   -inf <  1.383 <    inf | logz: -1.803 +/-  0.073 | dlogz:  0.016 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3658it [00:15, 34.00it/s, batch: 0 | bound: 113 | nc: 754 | ncall: 102167 | eff(%):  3.563 | loglstar:   -inf <  1.383 <    inf | logz: -1.803 +/-  0.073 | dlogz:  0.016 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3667it [00:16, 18.41it/s, batch: 0 | bound: 117 | nc: 6 | ncall: 104540 | eff(%):  3.491 | loglstar:   -inf <  1.383 <    inf | logz: -1.803 +/-  0.073 | dlogz:  0.016 >  0.010]  /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3695it [00:16, 47.02it/s, batch: 0 | bound: 118 | nc: 48 | ncall: 105289 | eff(%):  3.493 | loglstar:   -inf <  1.383 <    inf | logz: -1.802 +/-  0.073 | dlogz:  0.015 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3710it [00:16, 41.76it/s, batch: 0 | bound: 121 | nc: 56 | ncall: 108005 | eff(%):  3.419 | loglstar:   -inf <  1.383 <    inf | logz: -1.802 +/-  0.073 | dlogz:  0.015 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3716it [00:16, 42.86it/s, batch: 0 | bound: 122 | nc: 229 | ncall: 108472 | eff(%):  3.410 | loglstar:   -inf <  1.383 <    inf | logz: -1.802 +/-  0.073 | dlogz:  0.014 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3722it [00:17, 42.23it/s, batch: 0 | bound: 123 | nc: 374 | ncall: 109461 | eff(%):  3.385 | loglstar:   -inf <  1.383 <    inf | logz: -1.801 +/-  0.073 | dlogz:  0.014 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3805it [00:18, 97.90it/s, batch: 0 | bound: 131 | nc: 14 | ncall: 115227 | eff(%):  3.288 | loglstar:   -inf <  1.384 <    inf | logz: -1.799 +/-  0.073 | dlogz:  0.012 >  0.010]  /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3816it [00:18, 58.10it/s, batch: 0 | bound: 134 | nc: 162 | ncall: 117889 | eff(%):  3.223 | loglstar:   -inf <  1.384 <    inf | logz: -1.799 +/-  0.073 | dlogz:  0.012 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3832it [00:19, 51.91it/s, batch: 0 | bound: 137 | nc: 89 | ncall: 120164 | eff(%):  3.176 | loglstar:   -inf <  1.384 <    inf | logz: -1.799 +/-  0.073 | dlogz:  0.011 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3839it [00:19, 40.79it/s, batch: 0 | bound: 139 | nc: 123 | ncall: 121681 | eff(%):  3.142 | loglstar:   -inf <  1.384 <    inf | logz: -1.798 +/-  0.073 | dlogz:  0.011 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3864it [00:19, 52.54it/s, batch: 0 | bound: 143 | nc: 83 | ncall: 124038 | eff(%):  3.103 | loglstar:   -inf <  1.384 <    inf | logz: -1.798 +/-  0.073 | dlogz:  0.011 >  0.010] /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3873it [00:20, 44.44it/s, batch: 0 | bound: 145 | nc: 1096 | ncall: 125833 | eff(%):  3.066 | loglstar:   -inf <  1.384 <    inf | logz: -1.798 +/-  0.073 | dlogz:  0.010 >  0.010]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/bounding.py:618: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 13217it [00:26, 490.44it/s, batch: 9 | bound: 9 | nc: 1 | ncall: 205687 | eff(%):  6.317 | loglstar: -5.364 <  1.384 <  1.333 | logz: -1.763 +/-  0.040 | stop:  0.954]

# %%
from dynesty import plotting as dyplot
dyplot.cornerplot(sampler.results, span=([-6, 6], [-6, 6]), fig=plt.subplots(2, 2, figsize=(10, 10)));

# %%
import sys
import time
# bounding methods
sampling = ['unif', 'rwalk', 'slice', 'rslice', 'hslice']

# run over each method and collect our results
sampling_res = []
for s in sampling:
    sampler = dynesty.NestedSampler(loglike, prior_transform, ndim=2,
                                    bound='multi', sample=s, nlive=1000,
                                  )
    sys.stderr.flush()
    sys.stderr.write('{}:\n'.format(s))
    sys.stderr.flush()
    t0 = time.time()
    sampler.run_nested(dlogz=0.05)
    t1 = time.time()
    res = sampler.results
    dtime = t1 - t0
    sys.stderr.flush()
    sys.stderr.write('\ntime: {0}s\n\n'.format(dtime))
    sampling_res.append(sampler.results)
# Out:
# unif:
# 6156it [00:04, 1307.69it/s, +1000 | bound: 14 | nc: 1 | ncall: 57421 | eff(%): 12.683 | loglstar:   -inf <  1.384 <    inf | logz: -1.748 +/-  0.050 | dlogz:  0.000 >  0.050]
#
# time: 4.709146976470947s
#
# rwalk:
# 6172it [00:03, 2016.99it/s, +1000 | bound: 22 | nc: 1 | ncall: 93656 | eff(%):  7.740 | loglstar:   -inf <  1.384 <    inf | logz: -1.764 +/-  0.050 | dlogz:  0.000 >  0.050]
#
# time: 3.060847043991089s
#
# slice:
# 6090it [00:03, 1695.11it/s, +1000 | bound: 24 | nc: 1 | ncall: 153268 | eff(%):  4.656 | loglstar:   -inf <  1.384 <    inf | logz: -1.682 +/-  0.049 | dlogz:  0.000 >  0.050]
#
# time: 3.5935118198394775s
#
# rslice:
# 6166it [00:02, 2168.42it/s, +1000 | bound: 14 | nc: 1 | ncall: 129950 | eff(%):  5.557 | loglstar:   -inf <  1.384 <    inf | logz: -1.758 +/-  0.050 | dlogz:  0.000 >  0.050]
#
# time: 2.8443009853363037s
#
# hslice:
# 6281it [00:36, 174.35it/s, +1000 | bound: 23 | nc: 1 | ncall: 2542033 | eff(%):  0.287 | loglstar:   -inf <  1.384 <    inf | logz: -1.874 +/-  0.051 | dlogz:  0.000 >  0.050]
#
# time: 36.02500915527344s

# %%
 # bounding methods
bounds = ['none', 'single', 'multi', 'balls', 'cubes']

# run over each method and collect our results
bounds_res = []
for b in bounds:
    sampler = dynesty.NestedSampler(loglike, prior_transform, ndim=2,
                                    bound=b, sample='unif', nlive=500,
                                    first_update={'min_ncall': 0.,
                                                  'min_eff': 100.})
    sys.stderr.flush()
    sys.stderr.write('{}:\n'.format(b))
    sys.stderr.flush()
    t0 = time.time()
    sampler.run_nested(dlogz=0.05, maxcall=2000)
    t1 = time.time()
    res = sampler.results
    dtime = t1 - t0
    sys.stderr.flush()
    sys.stderr.write('\ntime: {0}s\n\n'.format(dtime))
    bounds_res.append(sampler.results)
# Out:
# none:
# 0it [00:00, ?it/s]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/sampler.py:756: UserWarning: The sampling was stopped short due to maxiter/maxcall limit the delta(log(z)) criterion is not achieved; posterior may be poorly sampled
#   warnings.warn('The sampling was stopped short due to'
# 786it [00:00, 7898.78it/s, +500 | bound: 1 | nc: 1 | ncall: 3009 | eff(%): 51.255 | loglstar:   -inf <  1.383 <    inf | logz: -1.726 +/-    nan | dlogz:  0.009 >  0.050]
#
# time: 0.10106110572814941s
#
# single:
# 0it [00:00, ?it/s]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/sampler.py:756: UserWarning: The sampling was stopped short due to maxiter/maxcall limit the delta(log(z)) criterion is not achieved; posterior may be poorly sampled
#   warnings.warn('The sampling was stopped short due to'
# 990it [00:00, 10334.58it/s, +500 | bound: 3 | nc: 1 | ncall: 3004 | eff(%): 59.505 | loglstar:   -inf <  1.383 <    inf | logz: -1.731 +/-    nan | dlogz:  0.006 >  0.050]
#
# time: 0.09645199775695801s
#
# multi:
# 831it [00:00, 2503.41it/s, bound: 3 | nc: 7 | ncall: 2006 | eff(%): 41.426 | loglstar:   -inf < -17.128 <    inf | logz: -22.356 +/-  0.093 | dlogz: 22.152 >  0.050]/Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/sampler.py:756: UserWarning: The sampling was stopped short due to maxiter/maxcall limit the delta(log(z)) criterion is not achieved; posterior may be poorly sampled
#   warnings.warn('The sampling was stopped short due to'
# 1056it [00:00, 2578.92it/s, +500 | bound: 3 | nc: 1 | ncall: 3001 | eff(%): 62.215 | loglstar:   -inf <  1.384 <    inf | logz: -1.805 +/-    nan | dlogz:  0.006 >  0.050]
#
# time: 0.41027092933654785s
#
# balls:
# 1072it [00:00, 1723.41it/s, bound: 3 | nc: 2 | ncall: 2209 | eff(%): 48.529 | loglstar:   -inf < -3.667 <    inf | logz: -8.274 +/-  0.086 | dlogz:  7.542 >  0.050]   /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/sampler.py:756: UserWarning: The sampling was stopped short due to maxiter/maxcall limit the delta(log(z)) criterion is not achieved; posterior may be poorly sampled
#   warnings.warn('The sampling was stopped short due to'
# 1191it [00:00, 1767.28it/s, +500 | bound: 3 | nc: 1 | ncall: 3001 | eff(%): 67.613 | loglstar:   -inf <  1.384 <    inf | logz: -1.680 +/-    nan | dlogz:  0.004 >  0.050]
#
# time: 0.6746511459350586s
#
# cubes:
# 1059it [00:00, 1736.45it/s, bound: 3 | nc: 2 | ncall: 2204 | eff(%): 48.049 | loglstar:   -inf < -5.467 <    inf | logz: -10.325 +/-  0.088 | dlogz:  9.626 >  0.050]  /Users/madiaz/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/sampler.py:756: UserWarning: The sampling was stopped short due to maxiter/maxcall limit the delta(log(z)) criterion is not achieved; posterior may be poorly sampled
#   warnings.warn('The sampling was stopped short due to'
# 1189it [00:00, 1762.42it/s, +500 | bound: 3 | nc: 1 | ncall: 3004 | eff(%): 67.452 | loglstar:   -inf <  1.384 <    inf | logz: -1.796 +/-    nan | dlogz:  0.004 >  0.050]
#
# time: 0.6753039360046387s

# %%
# initialize figure
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
axes = axes.reshape((1, 3))
[a.set_frame_on(False) for a in axes[:, 1]]
[a.set_xticks([]) for a in axes[:, 1]]
[a.set_yticks([]) for a in axes[:, 1]]

# plot proposals in corner format for 'single'
fg, ax = dyplot.cornerbound(bounds_res[1], it=2000, 
                            prior_transform=prior_transform,
                            show_live=True, fig=(fig, axes[:, 0]))
ax[0, 0].set_title('Single', fontsize=26)
ax[0, 0].set_xlim([-6.5, 6.5])
ax[0, 0].set_ylim([-6.5, 6.5])

# plot proposals in corner format for 'multi'
fg, ax = dyplot.cornerbound(bounds_res[2], it=2000, prior_transform=prior_transform,
                            show_live=True, fig=(fig, axes[:, 2]))
ax[0, 0].set_title('Multi', fontsize=26)
ax[0, 0].set_xlim([-6.5, 6.5])
ax[0, 0].set_ylim([-6.5, 6.5]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 9
#       6 [a.set_yticks([]) for a in axes[:, 1]]
#       8 # plot proposals in corner format for 'single'
# ----> 9 fg, ax = dyplot.cornerbound(bounds_res[1], it=2000,
#      10                             prior_transform=prior_transform,
#      11                             show_live=True, fig=(fig, axes[:, 0]))
#      12 ax[0, 0].set_title('Single', fontsize=26)
#      13 ax[0, 0].set_xlim([-6.5, 6.5])
#
# File ~/micromamba/envs/hep/lib/python3.11/site-packages/dynesty/plotting.py:1945, in cornerbound(results, it, idx, dims, prior_transform, periodic, reflective, ndraws, color, plot_kwargs, labels, label_kwargs, max_n_ticks, use_math_text, show_live, live_color, live_kwargs, span, fig)
#    1943 if it is not None:
#    1944     if it >= nsamps:
# -> 1945         raise ValueError("The iteration requested goes beyond the "
#    1946                          "number of iterations in the run.")
#    1947     # Extract bound iterations.
#    1948     try:
#
# ValueError: The iteration requested goes beyond the number of iterations in the run.

# %%
# initialize figure
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
axes = axes.reshape((1, 3))
[a.set_frame_on(False) for a in axes[:, 1]]
[a.set_xticks([]) for a in axes[:, 1]]
[a.set_yticks([]) for a in axes[:, 1]]

# plot proposals in corner format for 'balls'
fg, ax = dyplot.cornerbound(bounds_res[3], it=1500, prior_transform=prior_transform,
                            show_live=True, fig=(fig, axes[:, 0]))
ax[0, 0].set_title('Balls', fontsize=26)
ax[0, 0].set_xlim([-6.5, 6.5])
ax[0, 0].set_ylim([-6.5, 6.5])

# plot proposals in corner format for 'cubes'
fg, ax = dyplot.cornerbound(bounds_res[4], it=1500, prior_transform=prior_transform,
                            show_live=True, fig=(fig, axes[:, 2]))
ax[0, 0].set_title('Cubes', fontsize=26)
ax[0, 0].set_xlim([-6.5, 6.5])
ax[0, 0].set_ylim([-6.5, 6.5]);

# %%
from asp.search.mcmc import smooth_box_mask, smooth_mask
from asp.search.objective_fn import Objective

def booth(x):
    '''f(1,3)=0, -10 < x, y < 10'''
    x, y = x[0], x[1]
    term1 = (x+2*y-7)**2
    term2 = (2*x+y-5)**2
    return np.log(term1 + term2)

def himmelblau(x):
    '''-5 < x, y < 5'''
    x, y = x[0], x[1]
    term1 = (x**2+y-11)**2
    term2 = (x+y**2-7)**2
    return np.log(term1 + term2)


def himmelblau_booth(x):
    output = {
        'x': x[0],
        'y': x[1],
        'himmelblau': himmelblau(x),
        'booth': booth(x)
        }
    return output


space_config = {
    'x': {
        'lower': -5,
        'upper': 5.,
        'distribution': 'uniform',
    },
    'y': {
        'lower': -5,
        'upper': 5.,
        'distribution': 'uniform',
    },
}

output_parameters = ['himmelblau', 'booth']
input_parameters = ['x', 'y']

objectives = {
    'double_constraint': {
        'booth': [['gt', 2],['lt',4]]
    },
    'single_constraint': {
        'himmelblau':['lt', 3.],
    },
    'gaussian_constraint': {

    }
    }

objective_function = Objective(
            himmelblau_booth,
            space_config,
            input_parameters,
            output_parameters,
            objectives
            )

def him_boo(x):
    result = objective_function.sample(
        x.reshape(1,-1), is_normalised=True
    )
    h = result['himmelblau']
    b = result['booth']

    lh = 1 - smooth_mask(h,3., 1e-3)
    lb = smooth_box_mask(b, 2., 4., 1e-3 ) 
    return  np.log(lh*lb+ 1e-8)

# %%
import numpy as np


x = np.linspace(0, 1, 200)
y = np.linspace(0, 1, 200)
X, Y = np.meshgrid(x, y)


# Gaussian function
Z =  np.exp(-((X)**2 / (2) + (Y )**2 / (2)))

xy = np.vstack((X.flatten(), Y.flatten())).T

lhs = []
for point in xy:
    lhs.append(him_boo(point))

# %%
df = objective_function.as_dataframe()
df['lhs'] = lhs
df.head()
# Out:
#           x    y  himmelblau     booth  satisfactory        lhs
# 0 -5.000000 -5.0    5.521461  6.784457           0.0 -18.420681
# 1 -4.949749 -5.0    5.491246  6.777398           0.0 -18.420681
# 2 -4.899497 -5.0    5.462578  6.770317           0.0 -18.420681
# 3 -4.849246 -5.0    5.435556  6.763215           0.0 -18.420681
# 4 -4.798995 -5.0    5.410272  6.756092           0.0 -18.420681

# %%
import matplotlib.pyplot as plt 
text_configuration = {
    'usetex': True,
    'axes_labels_size': 14,
    'ticks_labels_size': 12,
    'legend_font_size': 12
}

plt.rc('text', usetex=True)
plt.rc('axes', titlesize=text_configuration['axes_labels_size'])
plt.rc('axes', labelsize=text_configuration['axes_labels_size'])
plt.rc('xtick', labelsize=text_configuration['ticks_labels_size'])
plt.rc('ytick', labelsize=text_configuration['ticks_labels_size'])
plt.rc('legend', fontsize=text_configuration['legend_font_size'])
plt.rc('axes', linewidth=0.2)

# %%
# Plot contour levels
fig, axs = plt.subplots(1,3, figsize=(9,3))
ax = axs[1]

ax.pcolormesh(
    df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape),
    df.himmelblau.to_numpy().reshape(Z.shape), 
           cmap='winter')
ax.contourf( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape),  
           df.himmelblau.to_numpy().reshape(Z.shape), 
           levels=[-10, 3], 
             colors='black',  alpha=0.3)
ax.contour( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape),  
           df.himmelblau.to_numpy().reshape(Z.shape), 
           levels=[-10, 3], 
              colors='black', alpha=0.5)
ax.set_title(r'$f_H(\theta_1, \theta_2)$')
#ax.clabel(contour, inline=True, fontsize=8)

ax = axs[0]

ax.pcolormesh( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape),
         df.booth.to_numpy().reshape(Z.shape), 
          cmap='winter')
ax.contourf( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape), 
           df.booth.to_numpy().reshape(Z.shape), 
           levels=[2, 4], 
              colors='black',  alpha=0.3)
ax.contour( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape),  
           df.booth.to_numpy().reshape(Z.shape), 
           levels=[2, 4], 
             colors='black', alpha=0.5)
ax.set_title(r'$f_B(\theta_1, \theta_2)$')



ax = axs[2]
Z_ = df.lhs.to_numpy().reshape(Z.shape)

contour_filled = ax.contourf( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape), Z_, levels=[-1, np.inf], colors='black', alpha=0.5)
ax.contour( df.x.to_numpy().reshape(X.shape),
    df.y.to_numpy().reshape(Y.shape), Z_, levels=[-1, np.inf], colors='black', alpha=0.5, linestyles='dotted')
ax.set_title(r'$\mathcal{S} \mathrm{\ region}$')
#plt.clabel(contour, inline=True, fontsize=8)
#ax.title('Contour Levels of a Gaussian Function')

#plt.grid(True)
#plt.colorbar()

for ax in axs:
    ax.set_xlabel(r'$\theta_1$')
    ax.set_ylabel(r'$\theta_2$')
plt.tight_layout()
plt.grid(True)
#plt.savefig('test_function_truth.pdf')
plt.show()

# %%
from asp.search.mcmc import metropolis_hastings, recursive_proposal, proposal_distribution
import numpy as np

# %%
x = np.random.uniform(-1,1,size=(2))
while not all(0 < element < 1 for element in x):
    print( all(0 < element < 1 for element in x))
    print(x)
    x = np.random.uniform(-1,1,size=(2))
print(x)
# Out:
# False
# [-0.72166582  0.6745363 ]
# [0.31248236 0.05898091]

# %%
x
# Out:
# array([0.31248236, 0.05898091])

# %%
success_hists = []
obj_fns  = []
for i in range(10):
    objective_function = Objective(
                himmelblau_booth,
                space_config,
                input_parameters,
                output_parameters,
                objectives
                )
    
    def him_boo(x):
        result = objective_function.sample(
            x.reshape(1,-1), is_normalised=True
        )
        h = result['himmelblau']
        b = result['booth']
    
        lh = 1 - smooth_mask(h,3., 1e-2)
        lb = smooth_box_mask(b, 2., 4., 1e-2 ) 
        return  lh*lb
    
    
    initial_x = np.random.uniform(0,1,size=(2))
    initial_lh = him_boo(initial_x)
    
    samples, total_proposal_history, total_proposal_likelihood, success_history = metropolis_hastings(
        him_boo,
        proposal_distribution,
        initial_x,
        initial_lh,
        initial_scale=.3,
        num_samples=2210,
        adapt_frequency=100,
        burn_in=1000
        )
    obj_fns.append(objective_function)

# %%
from asp.search.utils import dict_to_eval_string

lines = []
mcmc_dfs = []
for obj_fn in obj_fns:
    df = obj_fn.as_dataframe()
    samples = df.iloc[:, :2].to_numpy()
    print(len(samples))
    eval = dict_to_eval_string(objectives)
    select = df.eval(eval)
    df['s'] = select
    lines.append(select)
    mcmc_dfs.append(df)
# Out:
# 2211
# 2211
# 2211
# 2211
# 2211
# 2211
# 2211
# 2211
# 2211
# 2211

# %%
from mycolorpy import colorlist as mcp
color1=mcp.gen_color(cmap="winter",n=4)

# %%
color1
# Out:
# ['#0000ff', '#0055d4', '#00aaaa', '#00ff80']

# %%
import matplotlib.pyplot as plt 

obj_fn = obj_fns[np.random.randint(0,10)]
df = obj_fn.as_dataframe()
samples = df.iloc[:, :2].to_numpy()
print(len(samples))
eval = dict_to_eval_string(objectives)
select = df.eval(eval)
lines.append(select)
    
p_smpls = np.vstack(samples)[select]
n_smpls = np.vstack(samples)[~select]

px, py = p_smpls[:,0], p_smpls[:,1]
nx, ny = n_smpls[:,0], n_smpls[:,1]
# Create a figure
# Out:
# 2211

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

ys = []
for select in lines:
    y = np.cumsum(select)
    ys.append(y)
    ax.plot(range(len(y)), y, c=color1[1], alpha=0.1)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0), c=color1[0])

ax.set_ylabel(r'$\mathcal{S}\ \mathrm{Points}$')
ax.set_xlabel(r'$\mathrm{Step}$')

ax.grid()

plt.subplots_adjust(hspace=0.05)
plt.savefig('save/test_function_mcmcmh_10_runs_metrics.pdf')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp
color1=mcp.gen_color(cmap="winter",n=8)

class ScatterHistogramPlotter:
    def __init__(self, figsize=(3, 3)):
        # Initialize the figure and axes
        self.fig = plt.figure(figsize=figsize)
        self.scatter_ax = self.fig.add_axes([0.1, 0.1, 0.65, 0.65])
        self.x_hist_ax = self.fig.add_axes([0.1, 0.78, 0.65, 0.15], sharex=self.scatter_ax)
        self.y_hist_ax = self.fig.add_axes([0.78, 0.1, 0.15, 0.65], sharey=self.scatter_ax)
        
        # Configure the axes
        self.x_hist_ax.tick_params(labelleft=True, labelbottom=False)
        self.y_hist_ax.tick_params(labelbottom=True, labelleft=False)
        self.scatter_ax.set_xlabel(r'$\theta_1$')
        self.scatter_ax.set_ylabel(r'$\theta_2$')
        self.x_hist_ax.set_ylabel(r'$\mathrm{Count}$')
        self.y_hist_ax.set_xlabel(r'$\mathrm{Count}$')
        self.x_hist_ax.grid(False)
        self.y_hist_ax.grid(False)

    def add_scatter_points(self, X, Y, colors, alpha=0.7, s=2, labels=None):
        # Scatter plot

        self.scatter_ax.scatter(X, Y, s=s, c=colors, alpha=alpha)
        
        # Histograms
        self.x_hist_ax.hist(X, bins=30, color=colors, alpha=alpha)
        self.y_hist_ax.hist(Y, bins=30, orientation='horizontal', color=colors, alpha=alpha)
        
        # Adjust limits based on the scatter plot
        self.x_hist_ax.set_xlim(self.scatter_ax.get_xlim())
        self.y_hist_ax.set_ylim(self.scatter_ax.get_ylim())
        if labels:
            self.scatter_ax.set_xlabel(labels[0])
            self.scatter_ax.set_ylabel(labels[1])
    def show(self):
        plt.show()

# %%
plot = ScatterHistogramPlotter()
plot.add_scatter_points(nx, ny, colors=color1[1])
plot.add_scatter_points(px, py, colors=color1[-1])
plt.savefig('test_function_mcmcmh_run.pdf')

# %%
from pathlib import Path
from asp.search.objective_fn import ObjectiveDataSet
from asp.search.utils import dict_to_eval_string
import pandas as pd 

bcastor_dfs = []
bcastor_lines = []
for i in range(10):
    ods = ObjectiveDataSet()
    path = Path('/Users/madiaz/Documents/obsidian/Projects/active-search-pheno/experiments_paper/test_function/datasets/hb_bcastor_local')
    run_name = f'run_rdecay_long_17_{i}'
    ods.load_json(path / f'{run_name}/checkpoint')
    met = pd.read_csv(path / f'{run_name}/checkpointmetrics')
    df = pd.DataFrame(ods.dataset)
    filter_string = dict_to_eval_string(objectives)
    select = df.eval(filter_string)
    parameters = list(df.columns)
    df['s'] = select
    bcastor_dfs.append(df)
    bcastor_lines.append(select)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

ys = []
for select in bcastor_lines:
    y = np.cumsum(select)
    ys.append(y)
    ax.plot(range(len(y)), y, c=color1[3], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0), c=color1[2], label=f'b-CASTOR')


ys = []
for select in lines:
    y = np.cumsum(select)
    ys.append(y)
    ax.plot(range(len(y)), y, c=color1[-2], alpha=0.15)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0), c=color1[-3], label=f'MCMC-MH')


ax.set_ylabel(r'$\mathrm{Points} \in  \mathcal{S}$')
ax.set_xlabel(r'$\mathbf{f}_{B H}\ \mathrm{calls}$')

ax.grid()
plt.legend()
plt.subplots_adjust(hspace=0.05)
plt.savefig('save/test_function_bcastor_10_runs_s_points.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

ys = []
for select in bcastor_lines:
    y = np.cumsum(~select)
    ys.append(y)
    ax.plot(range(len(y)), y, c=color1[3], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0), c=color1[2], label=f'b-CASTOR')


ys = []
for select in lines:
    y = np.cumsum(~select)
    ys.append(y)
    ax.plot(range(len(y)), y, c=color1[-2], alpha=0.15)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0), c=color1[-3], label=f'MCMC-MH')


ax.set_ylabel(r'$\mathrm{Points} \notin  \mathcal{S}$')
ax.set_xlabel(r'$\mathbf{f}_{B H}\ \mathrm{calls}$')

ax.grid()
plt.legend()
plt.subplots_adjust(hspace=0.05)
plt.savefig('save/test_function_bcastor_10_runs_nons_points.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

ys = []
for select in bcastor_lines:
    y = np.cumsum(select)
    total = np.cumsum(range(len(select)))
    ys.append(y)
    ax.plot(range(len(y)), y/(np.arange(1, len(y)+1)), c=color1[3], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0)/(np.arange(1, len(y)+1)), c=color1[2], label=f'b-CASTOR')


ys = []
for select in lines:

    y = np.cumsum(select)
    ys.append(y)
    ax.plot(range(len(y)), y/(np.arange(1, len(y)+1)), c=color1[-2], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0)/(np.arange(1, len(y)+1)), c=color1[-3], label=f'MCMC-MH')


ax.set_ylabel(r'$\mathrm{Points} \in  \mathcal{S}/\ \mathrm{Total}$')
ax.set_xlabel(r'$\mathbf{f}_{B H}\ \mathrm{calls}$')

ax.grid()
plt.legend()
plt.subplots_adjust(hspace=0.05)
plt.savefig('save/test_function_bcastor_10_runs_metrics_s2total.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1, figsize=(4,3))

ys = []
for select in bcastor_lines:
    y = np.cumsum(~select)
    total = np.cumsum(range(len(select)))
    ys.append(y)
    ax.plot(range(len(y)), y/(np.arange(1, len(y)+1)), c=color1[3], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0)/(np.arange(1, len(y)+1)), c=color1[2], label=f'b-CASTOR')


ys = []
for select in lines:

    y = np.cumsum(~select)
    ys.append(y)
    ax.plot(range(len(y)), y/(np.arange(1, len(y)+1)), c=color1[-2], alpha=0.2)
ys = np.vstack(ys)
ax.plot(range(ys.shape[-1]), ys.mean(axis=0)/(np.arange(1, len(y)+1)), c=color1[-3], label=f'MCMC-MH')


ax.set_ylabel(r'$\mathrm{Points} \notin  \mathcal{S}/\ \mathrm{Total}$')
ax.set_xlabel(r'$\mathbf{f}_{B H}\ \mathrm{calls}$')

ax.grid()
plt.legend()
plt.subplots_adjust(hspace=0.05)
plt.savefig('save/test_function_bcastor_10_runs_metrics_nots2total.pdf',bbox_inches='tight')

# %%
ys.mean(axis=0)/range(len(y))
# Out:
# array([       inf, 1.63636364, 1.31818182, ..., 0.84733202, 0.84731882,
#        0.84738791])

# %%
rnd_fig_id = np.random.choice( range(10), 5,replace=False ) 
for i in rnd_fig_id:
    df = bcastor_dfs[i]
    plot = ScatterHistogramPlotter()
    select = df.s
    samples = df.iloc[:, :2].to_numpy()
    
    p_smpls = np.vstack(samples)[select]
    n_smpls = np.vstack(samples)[~select]
    
    px, py = p_smpls[:,0], p_smpls[:,1]
    nx, ny = n_smpls[:,0], n_smpls[:,1]
    
    plot.add_scatter_points(nx, ny, colors=color1[2])
    plot.add_scatter_points(px, py, colors=color1[-2])
    plot.show()
    plt.savefig(f'save/bcastor_tf_{i}.pdf',bbox_inches='tight')

# %%
rnd_fig_id = np.random.choice( range(10), 5,replace=False ) 
for i in rnd_fig_id:
    df = mcmc_dfs[i]
    plot = ScatterHistogramPlotter()
    select = df.s
    samples = df.iloc[:, :2].to_numpy()
    
    p_smpls = np.vstack(samples)[select]
    n_smpls = np.vstack(samples)[~select]
    
    px, py = p_smpls[:,0], p_smpls[:,1]
    nx, ny = n_smpls[:,0], n_smpls[:,1]
    
    plot.add_scatter_points(nx, ny, colors=color1[2])
    plot.add_scatter_points(px, py, colors=color1[-2])
    plot.show()
    plt.savefig(f'save/mcmc_tf_{i}.pdf',bbox_inches='tight')

# %%
len(bcastor_dfs[0])
# Out:
# 2210
